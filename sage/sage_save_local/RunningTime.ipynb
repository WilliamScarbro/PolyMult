# %%
#
import math

fft_mult = lambda n: 9/2*n*math.log(n,2)
kar_mult = lambda n : n**math.log(3,2)
def split(n):
    if n==2:
        return 0,2
    if n==4:
        
    
def ms_mult(n):
    if n==1:
        print(1,1)
        return 1
    N=n
    res=0
    while N>1:
        N=N//2
        res+=ms_mult(N)
    res+=math.log(n,2)
    print(n,res)
    return res

# %%
ms_mult(64)
# Out:
# 1 1
# 2 2.0
# 1 1
# 4 5.0
# 1 1
# 2 2.0
# 1 1
# 8 11.0
# 1 1
# 2 2.0
# 1 1
# 4 5.0
# 1 1
# 2 2.0
# 1 1
# 16 23.0
# 1 1
# 2 2.0
# 1 1
# 4 5.0
# 1 1
# 2 2.0
# 1 1
# 8 11.0
# 1 1
# 2 2.0
# 1 1
# 4 5.0
# 1 1
# 2 2.0
# 1 1
# 32 47.0
# 1 1
# 2 2.0
# 1 1
# 4 5.0
# 1 1
# 2 2.0
# 1 1
# 8 11.0
# 1 1
# 2 2.0
# 1 1
# 4 5.0
# 1 1
# 2 2.0
# 1 1
# 16 23.0
# 1 1
# 2 2.0
# 1 1
# 4 5.0
# 1 1
# 2 2.0
# 1 1
# 8 11.0
# 1 1
# 2 2.0
# 1 1
# 4 5.0
# 1 1
# 2 2.0
# 1 1
# 64 95.0
# 95.0

# %%
import matplotlib.pyplot as plt

x=range(1,1000)
fft_y = [fft_mult(i) for i in x]
kar_y = [kar_mult(i) for i in x]
ms_y = [ms_mult(i) for i in x]
split_y=[]
plt.plot(x,fft_y)
plt.plot(x,kar_y)
plt.plot(x,ms_y)

# %%
# Out:
# [1,
#  2.0,
#  2.584962500721156,
#  5.0,
#  5.321928094887362,
#  6.169925001442312,
#  6.39231742277876,
#  11.0,
#  11.169925001442312,
#  11.643856189774723,
#  11.78135971352466,
#  13.339850002884624,
#  13.45532722030456,
#  13.78463484555752,
#  13.884170519108434,
#  23.0,
#  23.08746284125034,
#  23.339850002884624,
#  23.417852514885897,
#  24.287712379549447,
#  24.358101707440845,
#  24.562719427049316,
#  24.626849764469032,
#  27.679700005769252,
#  27.738593694822818,
#  27.91065444060912,
#  27.9651022246315,
#  28.56926969111504,
#  28.619895764185006,
#  28.76834103821687,
#  28.815646752995228,
#  47.0,
#  47.04439411935845,
#  47.174925682500685,
#  47.21674585819531,
#  47.67970000576925,
#  47.71922836995589,
#  47.835705029771795,
#  47.87317973519046,
#  49.575424759098894,
#  49.61104866882962,
#  49.71620341488169,
#  49.750150746805026,
#  50.12543885409863,
#  50.157860331791014,
#  50.25369952893807,
#  50.28472642455869,
#  56.3594000115385,
# ...
